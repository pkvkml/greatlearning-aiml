# %% [markdown]
# [Basic Data Exploration](#basic-explor)
#
# [Bivariate analysis](#bivar)

# %%
pwd
# Out:
# 'C:\\Users\\Classroom'

# %% [markdown]
# # MODULE -1  -- Intro to pandas and basic concepts of data frames

# %% [markdown]
# DATA INPUT AND OUTPUT USING PANDAS
# CSV
# EXCEL
# HTML
# SQL
#
# When you install Jupyter via anaconda distribution, all the below packages come in by defauly
#
# When installing Jupyter outside anaconda distribution, you will need to use the following install commands
# Libraries that need to be installed with pip or conda
# conda install sqlalchemy
# conda install lxml
# conda install html5lib
# conda install BeautifulSoup4
#
# to read any file, type read_ and click tab

# %% [markdown]
# Data frames are 2d data structures .
# Data is aligned in a tabular format consists of rows and columns
# DataFrames can hold multiple data types
# DataFrames Constructor in pandas is
# pd.DataFrames(data=,index=,dtype=,copy)
# data holds the data source
# index holds the index to access the data source
# dtype is type of the data
# copy is self to false default. take a copy

# %%
import numpy as np
import pandas as pd
import random

# %%
from numpy.random import randn

# %%
random.randint(25,50)
# Out:
# 26

# %%
 #### we get the same set of random numbers
### initializes the random number generator. If you want to generate the same number 
### every time you need to pass the same seed value every time
## https://pynative.com/python-random-seed/

print('random number with seed 101')
random.seed(400) 

print("first--",random.randint(25,50))     ### will generate a random number

### to generate same random number as previous
random.seed(101)
print("second--",random.randint(25,50))     ### will generate a random number


### to generate same random number as previous
random.seed(101)
print("third--",random.randint(25,50))     ### will generate a random number
# Out:
# random number with seed 101
# first-- 34
# second-- 43
# third-- 43

# %%
x= randn(5,4)
# Out:
# array([[ 2.59781962, -0.67775046,  0.56744578,  1.97844588],
#        [ 0.04345596, -1.7584028 ,  1.48843799,  1.12672321],
#        [ 0.54995734,  0.56871716,  0.88751778, -2.26572798],
#        [-0.53814428,  0.42678795,  0.18748419, -0.52398804],
#        [-0.88043711,  0.20782092, -0.06080222, -0.92261489]])

# %%
#### creating a data frame using random number generator randn,use shift + tab to understand more about data frame parameters

df0 = pd.DataFrame(data=randn(5,4),index=['A','B','C','D','E'],columns= ['W','X','Y','Z'])

# %%
df0

#### each of the column W,X,Y,Z is each a pandas series sharing a common index
# Out:
#           W         X         Y         Z
# A  0.463705 -1.307084  0.655657  1.047360
# B -0.090134  0.080318 -0.543021 -0.924634
# C  0.254551  2.679607  1.169038 -2.714247
# D -0.100747 -0.884771  0.628771  0.227222
# E  1.564183 -0.025228  0.017931  1.090164

# %%
#### creating a data frame from a list
df_list = [['a1','b1','c1'],['a2','b2','c2'],['a3','b3','c3']]
df_list

#### to create user defined index, let us create a list of index
df_index = ['indx1','indx2','indx3']

# %%
### create dataframe from list
#data_Frame_list = pd.DataFrame(data=df_list)

data_Frame_list = pd.DataFrame(data=df_list,index=df_index,columns=('ColA','ColB','Colc'))
data_Frame_list
# Out:
#       ColA ColB Colc
# indx1   a1   b1   c1
# indx2   a2   b2   c2
# indx3   a3   b3   c3

# %%
#### creating a dataframe from dictionary
#### let us create a new diction
df_dict = {'k1':(1,2,3),'k2':(20,30,40),'k3':(30,40,50),'k4':[100,200,300],'k5':[100,200,300]}


### to make INDEXES FOR DATAFRAME
#data_Frame_dict = pd.DataFrame(data=df_dict,index=('I1','I2','I3','I4'),columns=('ColA','ColB','ColC','ColD'))
#data_Frame_dict


### to make INDEXES FOR DATAFRAME
#data_Frame_dict = pd.DataFrame(data=df_dict,index=('k1','k2','k3','k4'),columns=('ColA','ColB','ColC','ColD'))
#data_Frame_dict

# %%
### default creation
data_Frame_dict = pd.DataFrame(data=df_dict)
print(data_Frame_dict)
# Out:
#    k1  k2  k3   k4   k5
# 0   1  20  30  100  100
# 1   2  30  40  200  200
# 2   3  40  50  300  300

# %%
df00= pd.DataFrame({'col1':[1,2,3,4,5],'col2':[444,555,333,120,111],'col3':['abc','cde','def','efg','ghi']})
print(type(df00))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df00.head()                          ### returns the first n rows
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  cde
# 2     3   333  def
# 3     4   120  efg
# 4     5   111  ghi

# %%
df00.tail()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  cde
# 2     3   333  def
# 3     4   120  efg
# 4     5   111  ghi

# %%
df00
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  cde
# 2     3   333  def
# 3     4   120  efg
# 4     5   111  ghi

# %%
df00['col2'].unique()
# Out:
# array([444, 555, 333, 120, 111], dtype=int64)

# %%
### get information on unique values
df00['col2'].unique()                   ### gives me unique values in col2
# Out:
# array([444, 555, 333, 120, 111], dtype=int64)

# %%
### to get just the number of unique values in a column
df00['col2'].nunique()

### other way
### len(df['col2'].unique())
# Out:
# 5

# %%
df00['col2'].value_counts()        ### gives the number of counts each value was occuring = frequency table in r
# Out:
# 111    1
# 333    1
# 444    1
# 555    1
# 120    1
# Name: col2, dtype: int64

# %% [markdown]
# ####### Every column in a data frame is a series by itself
# ####### series is formed out of numpy arrays
#
# dataframe --> within dataframe there is series ==> within series you have numpy arrays

# %% [markdown]
# ### Changing data types

# %%
temp = pd.DataFrame({"A":["1","2","3"],"B":[11,12,13],"C": ["12-06-2012","13-06-2015","15-06-2017"]})

# %%
temp         ### not the keys in dictionary becomes columns and valuees become rows
# Out:
#    A   B           C
# 0  1  11  12-06-2012
# 1  2  12  13-06-2015
# 2  3  13  15-06-2017

# %%
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp["C"] = pd.to_datetime(temp["C"])

# %%
temp["A"] = pd.to_numeric(temp["A"])

# %%
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp["A"] = temp["A"].astype(str)

# %%
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp["D"] = pd.to_numeric(temp["A"])
temp
# Out:
#    A   B          C  D
# 0  1  11 2012-12-06  1
# 1  2  12 2015-06-13  2
# 2  3  13 2017-06-15  3

# %% [markdown]
# ### Creating Data Frames by reading files

# %%
## WE WILL USE THE FILE Uber Drives

# %%
## Pandas Libraries to be installed 
import pandas as pd
import numpy as np

# %%
# read the data in pandas

df = pd.read_csv("Uber Drives 2016.csv")

# %% [markdown]
# # Key Modules
#
# 1. Basic Dataframe operations
# 2. Common data manipulation tasks
# 3. Loops and Functions

# %% [markdown]
# ## Basic dataframe operations

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
### to return a random sample
#df2= df.sample(n=100000,replace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
# START_DATE*    1156 non-null object
# END_DATE*      1155 non-null object
# CATEGORY*      1155 non-null object
# START*         1155 non-null object
# STOP*          1155 non-null object
# MILES*         1156 non-null float64
# PURPOSE*       653 non-null object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
### Shape of data frame
df.shape 

## 1156 observations and 7 columns
# Out:
# (1156, 7)

# %%
### size of dataframe # a multiple of rows and columns
df.size
# Out:
# 8092

# %%
### datatypes of columns in a dataframe
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
### tells whether object has attribute with given name
hasattr(df,"head")
callable(getattr(df,"head"))
hasattr(df,"tail")
callable(getattr(df,"tail"))
# Out:
# True

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %% [markdown]
# ###### convert data to datetime format #### check this out
# ##### pd.to_datetime(df["START_DATE*"],format='%m/%d/%Y %H:%M')
#
# ###### Available time formats: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %% [markdown]
# ### Dataset summarization methods

# %% [markdown]
# ### The Describe Method
# -  is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values. When this method is applied to a series of string, it returns a different output
#
# - mean is the average and is the "expected" value of the distribution. On average, you'd expect to get this number.
#
# - std tells you how big of swings the data takes relative to the mean. Specifically, its the mean squared deviation from the mean.
#
# - 50% is also the median and marks the mid point of data in a column. This means half the scores are greater than or equal
#   to this value of median and half are less
#
# - 25% - lower quartile - 25% of scores fall below lower quartile
#
# -  75% - upper quartile - 75% of scores fall below the upper quartile value
#
# - min - minimum value
#
# - max - maximum value
#
#
# - count the larger this number, the more credibility all the stats have.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
# START_DATE*    1156 non-null object
# END_DATE*      1155 non-null object
# CATEGORY*      1155 non-null object
# START*         1155 non-null object
# STOP*          1155 non-null object
# MILES*         1156 non-null float64
# PURPOSE*       653 non-null object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df.describe()  ### will give summary statistics for numeric /quantitative variables only
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
print(df['CATEGORY*'].value_counts()) ### gives the count of each value in CATEGORY
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
df['MILES*'].value_counts().head()
# Out:
# 9.9     28
# 3.1     26
# 2.1     19
# 10.4    19
# 2.5     19
# Name: MILES*, dtype: int64

# %%
df.describe(include="all") ### will give summary statistics for all variables - 5 Point Summary

### NaN is missing values
### for quantitative all summary stats are shown
### for categorical only top,freq unique values are shown
### missing values are reported too
# Out:
#             START_DATE*        END_DATE* CATEGORY* START* STOP*        MILES*  \
# count              1156             1155      1155   1155  1155   1156.000000
# unique             1155             1154         2    177   188           NaN
# top     6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary           NaN
# freq                  2                2      1078    201   203           NaN
# mean                NaN              NaN       NaN    NaN   NaN     21.115398
# std                 NaN              NaN       NaN    NaN   NaN    359.299007
# min                 NaN              NaN       NaN    NaN   NaN      0.500000
# 25%                 NaN              NaN       NaN    NaN   NaN      2.900000
# 50%                 NaN              NaN       NaN    NaN   NaN      6.000000
# 75%                 NaN              NaN       NaN    NaN   NaN     10.400000
# max                 NaN              NaN       NaN    NaN   NaN  12204.700000
#
#        PURPOSE*
# count       653
# unique       10
# top     Meeting
# freq        187
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# ##### interpretation of describe
# top - gives the top occuring value in a given categorical column  (mode)
# freq  gives the frequency of times that a particular value occurs (example here "cary" occurs 201 times as start point
# unique = gives the unique occurrence of top occuring value "cary" 177 times
#
# mean - mean value of the column
# min - min value of column
# std - standard deviation of column
# 25% - 25th percentile value...meaning 75

# %%
### describe for individual columns
df["START_DATE*"].describe()
# Out:
# count                1156
# unique               1155
# top       6/28/2016 23:34
# freq                    2
# Name: START_DATE*, dtype: object

# %%
### describe for select group of columns
df[["START_DATE*","END_DATE*"]].describe()
# Out:
#             START_DATE*        END_DATE*
# count              1156             1155
# unique             1155             1154
# top     6/28/2016 23:34  6/28/2016 23:59
# freq                  2                2

# %%
# count of unique start locations
df["START*"].value_counts().head()
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Name: START*, dtype: int64

# %%
### gives  unique values in START*
df["START*"].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
#        'North Austin', 'Coxville', 'Convention Center District', 'Austin',
#        'Katy', 'Sharpstown', 'Sugar Land', 'Galveston', 'Port Bolivar',
#        'Washington Avenue', 'Briar Meadow', 'Latta', 'Jacksonville',
#        'Couples Glen', 'Kissimmee', 'Lake Reams', 'Orlando',
#        'Sand Lake Commons', 'Sky Lake', 'Daytona Beach', 'Ridgeland',
#        'Florence', 'Meredith', 'Holly Springs', 'Chessington', 'Burtrose',
#        'Parkway', 'Mcvan', 'Capitol One', 'University District',
#        'Seattle', 'Redmond', 'Bellevue', 'San Francisco', 'Palo Alto',
#        'Sunnyvale', 'Newark', 'Menlo Park', 'Old City', 'Savon Height',
#        'Kilarney Woods', 'Townes at Everett Crossing', 'Huntington Woods',
#        'Seaport', 'Medical Centre', 'Rose Hill', 'Soho', 'Tribeca',
#        'Financial District', 'Oakland', 'Emeryville', 'Berkeley',
#        'Kenner', 'CBD', 'Lower Garden District', 'Lakeview', 'Storyville',
#        'New Orleans', 'Metairie', 'Chalmette', 'Arabi',
#        'Pontchartrain Shores', 'Marigny', 'Covington', 'Mandeville',
#        'Jamestown Court', 'Summerwinds', 'Parkwood',
#        'Pontchartrain Beach', 'St Thomas', 'Banner Elk', 'Elk Park',
#        'Newland', 'Boone', 'Stonewater', 'Lexington Park at Amberly',
#        'Arlington Park at Amberly', 'Arlington', 'Kalorama Triangle',
#        'K Street', 'West End', 'Connecticut Avenue', 'Columbia Heights',
#        'Washington', 'Wake Forest', 'Lahore', 'Karachi', 'SOMISSPO',
#        'West Berkeley', 'North Berkeley Hills', 'San Jose', 'Eagle Rock',
#        'Winston Salem', 'Asheville', 'Topton', 'Hayesville',
#        'Bryson City', 'Almond', 'Mebane', 'Agnew', 'Cory', 'Renaissance',
#        'Santa Clara', 'NOMA', 'Sunnyside', 'Ingleside', 'Central',
#        'Tenderloin', 'College Avenue', 'South', 'Southside',
#        'South Berkeley', 'Mountain View', 'El Cerrito', 'Krendle Woods',
#        'Wake Co.', 'Fuquay-Varina', 'Rawalpindi', 'Kar?chi', 'Katunayake',
#        'Gampaha', nan], dtype=object)

# %%
#NUMBER OF  unique value in START*
df["START*"].nunique()
# Out:
# 177

# %%
### count of each value in START*

df["START*"].value_counts().head()
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Name: START*, dtype: int64

# %%
#### median of a dataframe
#### gives the median of the numeric columns MILES
import statistics
df.median()
# Out:
# MILES*    6.0
# dtype: float64

# %%
### column   median -  adds up all the values in a given column and finds the mid point. same as df.median
df.median(axis=0)
# Out:
# MILES*    6.0
# dtype: float64

# %%
### median of a specific column
#df['MILES*'].median()
df.loc[:,"MILES*"].median()
# Out:
# 6.0

# %%
### mode  
df.mode()
# Out:
#        START_DATE*        END_DATE* CATEGORY* START* STOP*  MILES* PURPOSE*
# 0  6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary     9.9  Meeting

# %% [markdown]
# ---

# %% [markdown]
# ## Common data manipulation tasks
# ### 1. Renaming Columns

# %%
dfnew = pd.read_csv("Uber Drives 2016.csv")

# %%
### renaming column names in dataframe
dfnew.rename(columns={'START_DATE*' : 'start_date',
                    'END_DATE*'  : 'end_date',
                     'CATEGORY*' : 'category',
                     'START*'    : 'start',
                     'STOP*'     : 'stop',
                     'MILES*'    :  'miles',
                     'PURPOSE*'   :  'purpose' }, 
                 inplace=False).head()
# Out:
#        start_date        end_date  category        start             stop  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    miles          purpose
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
### renames columns with the first 3 chars of each column
dfnew.rename(columns=lambda x: x[0:3], inplace=False).head()
# Out:
#               STA             END       CAT          STA              STO  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#     MIL              PUR
# 0   5.1   Meal/Entertain
# 1   5.0              NaN
# 2   4.8  Errand/Supplies
# 3   4.7          Meeting
# 4  63.7   Customer Visit

# %%
##How To Change and Row Names/Indexes in Pandas?
dfnew.rename(index={0:'zero',1:'one'}, inplace=False).head()
# Out:
#          START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# zero  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# one    1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2     1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3     1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4     1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#       MILES*         PURPOSE*
# zero     5.1   Meal/Entertain
# one      5.0              NaN
# 2        4.8  Errand/Supplies
# 3        4.7          Meeting
# 4       63.7   Customer Visit

# %%
##How To Change Column Names and Row Indexes Simultaneously in Pandas?
dfnew.rename(columns={'START_DATE*' : 'start_date',
                    'END_DATE*'  : 'end_date',
                     'CATEGORY*' : 'category',
                     'START*'    : 'start',
                     'STOP*'     : 'stop',
                     'MILES*'    :  'miles',
                     'PURPOSE*'   :  'purpose'}, 
                 index={0:'zero',1:'one'}, 
                 inplace=False).head(3)
# Out:
#           start_date        end_date  category        start         stop  \
# zero  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce  Fort Pierce
# one    1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce  Fort Pierce
# 2     1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce  Fort Pierce
#
#       miles          purpose
# zero    5.1   Meal/Entertain
# one     5.0              NaN
# 2       4.8  Errand/Supplies

# %% [markdown]
# ## Common data manipulation tasks
# ### 2. Select /Indexing

# %% [markdown]
# 5 verbs of data manipulation
#
# 1. Selecting/Indexing
# 2. Filtering
# 3. Sorting
# 4. Mutating/ Conditionally adding columns
# 5. Groupby/Summarize

# %%
### retreiving /accessing/grabbing/extracting data from a dataframe

# %%
### Permanently renaming columns
dfnew.rename(columns={'START_DATE*' : 'start_date',
                    'END_DATE*'  : 'end_date',
                     'CATEGORY*' : 'category',
                     'START*'    : 'start',
                     'STOP*'     : 'stop',
                     'MILES*'    :  'miles',
                     'PURPOSE*'   :  'purpose'}, 
                 index={0:'zero',1:'one'}, 
                 inplace=True)

# %%
dfnew.head()
# Out:
#           start_date        end_date  category        start             stop  \
# zero  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# one    1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2     1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3     1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4     1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#       miles          purpose
# zero    5.1   Meal/Entertain
# one     5.0              NaN
# 2       4.8  Errand/Supplies
# 3       4.7          Meeting
# 4      63.7   Customer Visit

# %% [markdown]
#  ### Selecting Columns from a data frame

# %%
#### To retrieve a column  
dfnew['start_date'].head()
# Out:
# zero    1/1/2016 21:11
# one      1/2/2016 1:25
# 2       1/2/2016 20:25
# 3       1/5/2016 17:31
# 4       1/6/2016 14:42
# Name: start_date, dtype: object

# %%
#### To retrieve multiple columns ..note the twin square brackets
dfnew[['start_date','end_date','miles']].head()
# Out:
#           start_date        end_date  miles
# zero  1/1/2016 21:11  1/1/2016 21:17    5.1
# one    1/2/2016 1:25   1/2/2016 1:37    5.0
# 2     1/2/2016 20:25  1/2/2016 20:38    4.8
# 3     1/5/2016 17:31  1/5/2016 17:45    4.7
# 4     1/6/2016 14:42  1/6/2016 15:49   63.7

# %%
#### to retrieve information from data frame

###
print(type(dfnew))

### extracting top and bottom 5 rows of a column START_DATE* from dataframe df 
print(dfnew['start_date'].head())
print('/n')
print(dfnew['start_date'].tail())


#### note that the output is a series with user defined indexes and also its uni dimensional
# Out:
# <class 'pandas.core.frame.DataFrame'>
# zero    1/1/2016 21:11
# one      1/2/2016 1:25
# 2       1/2/2016 20:25
# 3       1/5/2016 17:31
# 4       1/6/2016 14:42
# Name: start_date, dtype: object
# /n
# 1151    12/31/2016 13:24
# 1152    12/31/2016 15:03
# 1153    12/31/2016 21:32
# 1154    12/31/2016 22:08
# 1155              Totals
# Name: start_date, dtype: object

# %%
### to verify whether every column in a data frame is a series or not
type(dfnew['start_date'])
# Out:
# pandas.core.series.Series

# %%
### alternate way to retrieve data from df. THIS IS NOT RECOMMENDED 
### because using '.' can get confused with 
#### using methods

# %%
dfnew.head()
# Out:
#           start_date        end_date  category        start             stop  \
# zero  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# one    1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2     1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3     1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4     1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#       miles          purpose
# zero    5.1   Meal/Entertain
# one     5.0              NaN
# 2       4.8  Errand/Supplies
# 3       4.7          Meeting
# 4      63.7   Customer Visit

# %%
### 2 or more columns twin sq brackets are enough
dfnew[['start_date','end_date','category']].head()

#### Double bracket notation is enough to extract more than 1 column
# Out:
#           start_date        end_date  category
# zero  1/1/2016 21:11  1/1/2016 21:17  Business
# one    1/2/2016 1:25   1/2/2016 1:37  Business
# 2     1/2/2016 20:25  1/2/2016 20:38  Business
# 3     1/5/2016 17:31  1/5/2016 17:45  Business
# 4     1/6/2016 14:42  1/6/2016 15:49  Business

# %% [markdown]
# ### conditional selection

# %%
## retreive all rows where miles is greater than 4
dfnew_cond = dfnew['miles'] > 4
dfnew_cond.head(10)


### smart coding - #### using bracket notation, we can get only the rows where this cond is satisfied
### grab only rows of col miles where its > 4
dfnew[dfnew['miles']>4].head()
# Out:
#           start_date        end_date  category        start             stop  \
# zero  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# one    1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2     1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3     1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4     1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#       miles          purpose
# zero    5.1   Meal/Entertain
# one     5.0              NaN
# 2       4.8  Errand/Supplies
# 3       4.7          Meeting
# 4      63.7   Customer Visit

# %% [markdown]
# ### Conditionally adding columns
# Feature Engineering

# %%
### if we want to add a column called miles category with 2 categories as Long Trip and Short Trip
import numpy as np
dfnew["miles_cat"] = np.where(dfnew["miles"] > 5,"Long Trip","Short Trip")

# %%
dfnew.head()
# Out:
#           start_date        end_date  category        start             stop  \
# zero  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# one    1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2     1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3     1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4     1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#       miles          purpose   miles_cat
# zero    5.1   Meal/Entertain   Long Trip
# one     5.0              NaN  Short Trip
# 2       4.8  Errand/Supplies  Short Trip
# 3       4.7          Meeting  Short Trip
# 4      63.7   Customer Visit   Long Trip

# %%
dfnew["miles_cat"].value_counts()
# Out:
# Long Trip     654
# Short Trip    502
# Name: miles_cat, dtype: int64

# %%
dfnew.loc[dfnew["miles"] > 5].shape
# Out:
# (654, 8)

# %% [markdown]
# ### Filtering

# %%
### all rows with miles greater than 10
df2 = dfnew.loc[dfnew["miles"] > 10,["miles"]]
df2
# Out:
#         miles
# 4        63.7
# 9        16.5
# 10       10.8
# 22       15.1
# 23       11.2
# 24       11.8
# 25       21.9
# 28       10.4
# 29       10.4
# 34       17.1
# 35       15.1
# 36       40.2
# 46       18.7
# 49       12.9
# 50       19.0
# 51       14.7
# 52       15.7
# 55       10.4
# 56       10.1
# 61       19.4
# 62       23.3
# 74       10.4
# 75       10.4
# 76       11.4
# 91       17.3
# 93       13.5
# 97       17.0
# 98       18.0
# 100      11.5
# 106      13.0
# ...       ...
# 998      11.1
# 1002     13.3
# 1035     18.9
# 1036     15.6
# 1037     15.6
# 1054     10.6
# 1058     10.2
# 1067     10.2
# 1070     11.0
# 1071     12.0
# 1073     19.4
# 1078     10.3
# 1079     11.5
# 1082     16.2
# 1087     12.0
# 1088    103.0
# 1089     32.3
# 1091     11.6
# 1092     23.2
# 1094     12.3
# 1095     14.0
# 1104     10.7
# 1125     10.3
# 1126     10.4
# 1133     11.6
# 1134     11.9
# 1144     12.9
# 1152     16.2
# 1154     48.2
# 1155  12204.7
#
# [316 rows x 1 columns]

# %%
df3 = df2.iloc[0:3]
df3
# Out:
#     miles
# 4    63.7
# 9    16.5
# 10   10.8

# %%
# find out all rides greater than 10 miles
dfnew.loc[dfnew["miles"] > 10].head()

# %%
# Find out all rides to Cary
#dfnew[dfnew['start']=="Cary",dfnew["miles"]].head()

dfnew[(dfnew['start']=="Cary") & (dfnew['miles'] > 4)][['start','category','start_date']]
# Out:
#      start  category        start_date
# 8     Cary  Business    1/10/2016 8:05
# 28    Cary  Business   1/15/2016 11:43
# 30    Cary  Business   1/18/2016 14:55
# 34    Cary  Business   1/20/2016 10:36
# 46    Cary  Business   1/27/2016 10:19
# 50    Cary  Business   1/28/2016 12:28
# 53    Cary  Business    1/29/2016 9:31
# 54    Cary  Business   1/29/2016 10:56
# 55    Cary  Business   1/29/2016 11:43
# 57    Cary  Business   1/29/2016 18:31
# 59    Cary  Business   1/30/2016 16:21
# 61    Cary  Business    2/1/2016 10:35
# 65    Cary  Business    2/2/2016 13:51
# 67    Cary  Business     2/4/2016 8:40
# 73    Cary  Business    2/4/2016 20:36
# 74    Cary  Business    2/5/2016 11:47
# 76    Cary  Business    2/6/2016 16:20
# 79    Cary  Business    2/7/2016 16:49
# 81    Cary  Business    2/7/2016 18:39
# 89    Cary  Business    2/9/2016 18:55
# 91    Cary  Business   2/11/2016 16:28
# 95    Cary  Business    2/12/2016 8:21
# 99    Cary  Business   2/12/2016 14:49
# 101   Cary  Business   2/13/2016 14:21
# 164   Cary  Business   2/26/2016 11:35
# 181   Cary  Business    3/3/2016 15:27
# 183   Cary  Business     3/4/2016 7:47
# 28           Durham   10.4   Meal/Entertain   Long Trip
# 30             Cary    4.8   Meal/Entertain  Short Trip
# 34          Raleigh   17.1          Meeting   Long Trip
# 37             Cary    1.6  Errand/Supplies  Short Trip
# 38             Cary    2.4   Meal/Entertain  Short Trip
# 39             Cary    1.0   Meal/Entertain  Short Trip
# 43             Cary    1.4  Errand/Supplies  Short Trip
# 44             Cary    0.5  Errand/Supplies  Short Trip
# 45             Cary    1.8          Meeting  Short Trip
# 46          Raleigh   18.7   Customer Visit   Long Trip
# 50          Raleigh   19.0   Temporary Site   Long Trip
# 53             Cary    4.6   Customer Visit  Short Trip
# 54             Cary    5.2          Meeting   Long Trip
# 55           Durham   10.4          Meeting   Long Trip
# 57             Apex    5.8  Errand/Supplies   Long Trip
# 59             Apex    5.7  Errand/Supplies   Long Trip
# 61      Chapel Hill   19.4   Customer Visit   Long Trip
# 65             Cary    6.0  Errand/Supplies   Long Trip
# 66             Cary    1.6  Errand/Supplies  Short Trip
# 67      Morrisville    5.2  Errand/Supplies   Long Trip
# 68             Cary    9.7   Meal/Entertain   Long Trip
# 69             Cary    1.6   Meal/Entertain  Short Trip
# 70             Cary    1.1   Meal/Entertain  Short Trip
# 71             Cary    1.6   Meal/Entertain  Short Trip
# 73             Cary    7.7          Meeting   Long Trip
# 74           Durham   10.4          Meeting   Long Trip
# 76          Raleigh   11.4  Between Offices   Long Trip
# ...             ...    ...              ...         ...
# 1022           Cary    4.1              NaN  Short Trip
# 1023           Cary    3.8   Meal/Entertain  Short Trip
# 1024           Cary    6.6          Meeting   Long Trip
# 1025           Cary    4.0          Meeting  Short Trip
# 1026           Cary    7.0   Customer Visit   Long Trip
# 1027           Cary    6.9   Meal/Entertain   Long Trip
# 1028           Cary    3.4  Errand/Supplies  Short Trip
# 1029           Cary    3.4  Errand/Supplies  Short Trip
# 1030           Cary    2.0          Meeting  Short Trip
# 1031           Cary    2.0  Errand/Supplies  Short Trip
# 1032           Apex    5.1  Errand/Supplies   Long Trip
# 1034           Cary    5.6          Meeting   Long Trip
# 1035           Cary   18.9   Customer Visit   Long Trip
# 1036  Fuquay-Varina   15.6          Meeting   Long Trip
# 1038    Morrisville    3.0   Meal/Entertain  Short Trip
# 1039           Cary    3.1   Customer Visit  Short Trip
# 1040    Morrisville    3.0   Meal/Entertain  Short Trip
# 1041           Cary    4.8  Errand/Supplies  Short Trip
# 1042           Cary    2.1  Errand/Supplies  Short Trip
# 1043           Cary    3.1  Errand/Supplies  Short Trip
# 1044           Apex    4.4   Meal/Entertain  Short Trip
# 1046    Morrisville    3.0   Meal/Entertain  Short Trip
# 1047           Cary    3.0   Customer Visit  Short Trip
# 1048           Cary    4.2  Errand/Supplies  Short Trip
# 1049           Cary    4.1   Meal/Entertain  Short Trip
# 1050           Cary    3.4              NaN  Short Trip
# 1051           Cary    3.3              NaN  Short Trip
# 1052    Morrisville    3.0   Meal/Entertain  Short Trip
# 1053           Cary    3.1   Customer Visit  Short Trip
# 1054    Morrisville   10.6          Meeting   Long Trip
#
# [286 rows x 8 columns]

# %%
 # Find out all rides to Cary & Morrisville          
dfnew[dfnew["start"].isin(["Cary","Morrisville"])].shape

# %%
# Find out all rides to Cary & Morrisville          
dfnew.loc[dfnew["start"].isin(["Cary","Morrisville"])].head()
# Out:
#          start_date         end_date  category        start         stop  \
# 7    1/7/2016 13:27   1/7/2016 13:33  Business         Cary         Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business         Cary  Morrisville
# 27   1/15/2016 0:41   1/15/2016 1:01  Business  Morrisville         Cary
# 28  1/15/2016 11:43  1/15/2016 12:03  Business         Cary       Durham
# 30  1/18/2016 14:55  1/18/2016 15:06  Business         Cary         Cary
#
#     miles          purpose   miles_cat
# 7     0.8          Meeting  Short Trip
# 8     8.3          Meeting   Long Trip
# 27    8.0  Errand/Supplies   Long Trip
# 28   10.4   Meal/Entertain   Long Trip
# 30    4.8   Meal/Entertain  Short Trip

# %%
dfnew.loc[~dfnew["start"].isin(["Cary","Morrisville"])].head()

# %%
dfnew.describe()

# %%
dfnew[dfnew_cond].head(10)

# %%
### multiple conditions using and 
#### using bracket notation, we can get only the rows where this cond is satisfied
### grab only rows of col miles where its >2 and < 4
dfnew_cond1 = (dfnew['miles']>2) & (dfnew['miles']<4)
print(dfnew[dfnew_cond1].head())

### Alternate way of smart coding
print(dfnew[(dfnew['miles']>2) & (dfnew['miles']<4)].head(5))
# Out:
#          start_date         end_date  category          start  \
# 20  1/12/2016 15:13  1/12/2016 15:28  Business  Hudson Square
# 26  1/14/2016 21:39  1/14/2016 21:45  Business     Eagan Park
# 38  1/21/2016 14:43  1/21/2016 14:51  Business           Cary
# 41  1/26/2016 12:33  1/26/2016 12:41  Business      Hazelwood
# 47  1/27/2016 12:34  1/27/2016 12:44  Business       Fairmont
#
#                stop  miles          purpose   miles_cat
# 20   Hell's Kitchen    2.4   Customer Visit  Short Trip
# 26  Jamestown Court    3.9  Errand/Supplies  Short Trip
# 38             Cary    2.4   Meal/Entertain  Short Trip
# 41      Whitebridge    2.3  Errand/Supplies  Short Trip
# 47  Meredith Townes    3.4   Customer Visit  Short Trip
#          start_date         end_date  category          start  \
# 20  1/12/2016 15:13  1/12/2016 15:28  Business  Hudson Square
# 26  1/14/2016 21:39  1/14/2016 21:45  Business     Eagan Park
# 38  1/21/2016 14:43  1/21/2016 14:51  Business           Cary
# 41  1/26/2016 12:33  1/26/2016 12:41  Business      Hazelwood
# 47  1/27/2016 12:34  1/27/2016 12:44  Business       Fairmont
#
#                stop  miles          purpose   miles_cat
# 20   Hell's Kitchen    2.4   Customer Visit  Short Trip
# 26  Jamestown Court    3.9  Errand/Supplies  Short Trip
# 38             Cary    2.4   Meal/Entertain  Short Trip
# 41      Whitebridge    2.3  Errand/Supplies  Short Trip
# 47  Meredith Townes    3.4   Customer Visit  Short Trip

# %%
dfnew_cond2 = (df['miles']>2) | (df['miles']<4)
dfnew_cond2.head()
dfnew[dfnew_cond2].head()

# %% [markdown]
# ##### Extracting data from a resultset of

# %%
dfnew_cond2 = dfnew[(dfnew['miles']>2) & (dfnew['miles']<4)]
print(dfnew_cond2.head())

# %%
##### extracting data from the above resultset - eg extract column X from result set
### watch the double square brackets after condition
dfnew[(dfnew['miles']>2) & (dfnew['miles']<4)][['start','category','start_date']].head()

# %% [markdown]
# ### Column addition and deletion - Feature Engineering

# %%
#### creating a new column  - helps in feature creation
### df['new']   returns error that new column is not found

#### correct way of creating a new column or feature

dfnew['new_col1']  = dfnew['end_date'] + dfnew['start_date']
dfnew['new_col2'] = dfnew['miles'] * 2
dfnew.head()

##mylistdf = [10000,20000,3000,49999,590000]

##mylistdf

### you see new_col and new_Col1
# Out:
#           start_date        end_date  category        start             stop  \
# zero  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# one    1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2     1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3     1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4     1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#       miles          purpose   miles_cat                      new_col1  \
# zero    5.1   Meal/Entertain   Long Trip  1/1/2016 21:171/1/2016 21:11
# one     5.0              NaN  Short Trip    1/2/2016 1:371/2/2016 1:25
# 2       4.8  Errand/Supplies  Short Trip  1/2/2016 20:381/2/2016 20:25
# 3       4.7          Meeting  Short Trip  1/5/2016 17:451/5/2016 17:31
# 4      63.7   Customer Visit   Long Trip  1/6/2016 15:491/6/2016 14:42
#
#       new_col2
# zero      10.2
# one       10.0
# 2          9.6
# 3          9.4
# 4        127.4

# %%
### try printing it again and you  see the new columns
dfnew.head()

# %%
## TO DROP A COLUMN

# %%
dfnew.drop('new_col1')
print(dfnew)

### this will give an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-d5fd73c86142> in <module>()
# ----> 1 dfnew.drop('new_col1')
#       2 print(dfnew)
#       3
#       4 ### this will give an error
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: "labels ['new_col1'] not contained in axis"

# %%
### default axis for columns is axis 1, rows is axis 0
dfnew.drop('new_col1',axis=1,inplace=False)
### this will drop the column but not permanently
# Out:
#             start_date          end_date  category              start  \
# zero    1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# one      1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# 12     1/10/2016 19:12   1/10/2016 19:32  Business            Midtown
# 13      1/11/2016 8:55    1/11/2016 9:21  Business        East Harlem
# 14     1/11/2016 11:56   1/11/2016 12:03  Business  Flatiron District
# 15     1/11/2016 13:32   1/11/2016 13:46  Business            Midtown
# 16     1/11/2016 14:30   1/11/2016 14:43  Business       Midtown East
# 17     1/12/2016 12:33   1/12/2016 12:49  Business            Midtown
# 18     1/12/2016 12:53   1/12/2016 13:09  Business      Hudson Square
# 1147           Kar?chi      4.6  Errand/Supplies  Short Trip       9.2
# 1148           Kar?chi      4.6          Meeting  Short Trip       9.2
# 1149           Kar?chi      0.8   Customer Visit  Short Trip       1.6
# 1150           Kar?chi      0.7          Meeting  Short Trip       1.4
# 1151  Unknown Location      3.9   Temporary Site  Short Trip       7.8
# 1152  Unknown Location     16.2          Meeting   Long Trip      32.4
# 1153           Gampaha      6.4   Temporary Site   Long Trip      12.8
# 1154         Ilukwatta     48.2   Temporary Site   Long Trip      96.4
# 1155               NaN  12204.7              NaN   Long Trip   24409.4
#
# [1156 rows x 9 columns]

# %%
### inplace = True needs to be given to permanently drop the column. default inplace is False. we can still see the column new_col1
dfnew.columns
# Out:
# Index(['start_date', 'end_date', 'category', 'start', 'stop', 'miles',
#        'purpose', 'miles_cat', 'new_col1', 'new_col2'],
#       dtype='object')

# %%
### to permanently drop
dfnew.drop('new_col1',axis=1,inplace=True)

# %%
### check validate
dfnew.columns
# Out:
# Index(['start_date', 'end_date', 'category', 'start', 'stop', 'miles',
#        'purpose', 'miles_cat', 'new_col2'],
#       dtype='object')

# %% [markdown]
# #### ROW SELECTION

# %%
dfnew.head()

# %%
#### selecting rows, by using .loc method. .loc is followed by [] and not ()
### prints the entire row with index 2
print(dfnew.loc['zero'])  ### first row
print('/n)')
print('/n)')
print(dfnew.loc[2])     #### third row

# %%
### ALTERNATE WAY OF EXTRACTING ROWS FROM A DATA FRAME
#### index location based look up
 
print(dfnew.iloc[0])
print('\n')
print(dfnew.iloc[2])
# Out:
# start_date    1/1/2016 21:11
# end_date      1/1/2016 21:17
# category            Business
# start            Fort Pierce
# stop             Fort Pierce
# miles                    5.1
# purpose       Meal/Entertain
# miles_cat          Long Trip
# new_col2                10.2
# Name: zero, dtype: object
#
#
# start_date     1/2/2016 20:25
# end_date       1/2/2016 20:38
# category             Business
# start             Fort Pierce
# stop              Fort Pierce
# miles                     4.8
# purpose       Errand/Supplies
# miles_cat          Short Trip
# new_col2                  9.6
# Name: 2, dtype: object

# %%
dfnew.head()

# %%
#### to extract subset of rows and columns - example row zero and Column start - 'Fort Pierce'
dfnew.loc['zero','start']
# Out:
# 'Fort Pierce'

# %%
#### SUBSETTING -Example 2 - extract values in row zero and one, columns start and stop
### df1.loc[[row indexes], [column indexes]]

dfnew.loc[['zero','one'],['start','stop']]

# %%
dfnew.loc[['zero','one',2],['start','stop','miles']]

# %%
### extracting rows using iloc and slice notation - slice notations apply..go up to a row, but not include that row index
dfnew.iloc[0:2]

# %%
### extracting rows using iloc and slice notation - slice notations apply..go up to a row, but not include that row index
dfnew.iloc[0:2][['start','stop','miles']]

# %%
## extracts rows with index 0 and 1 and columns 0 and 3
dfnew.iloc[0:2,[0,3]]

# %% [markdown]
# ### Sorting

# %%
dfnew.sort_values(by=['miles'],ascending=False).head(5)
# Out:
#             start_date          end_date  category             start  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 469                    Metairie     17.0   Meal/Entertain   Long Trip
# 621                  Washington      4.9              NaN  Short Trip
# 613   Lexington Park at Amberly      1.3              NaN  Short Trip
# 881                      Mebane    195.9              NaN   Long Trip
# 871                      Topton     91.8          Meeting   Long Trip
# 232                        Katy    136.0   Customer Visit   Long Trip
# 552                     Newland     28.1              NaN   Long Trip
# 549                    Elk Park     22.4              NaN   Long Trip
# ...                         ...      ...              ...         ...
# 632              Edgehill Farms      2.7              NaN  Short Trip
# 174                   Hazelwood      2.6              NaN  Short Trip
# 898                   Hazelwood      2.5              NaN  Short Trip
# 178              Westpark Place      2.2              NaN  Short Trip
# 348              Westpark Place      2.2  Errand/Supplies  Short Trip
# 599              Westpark Place      2.2              NaN  Short Trip
# 607              Westpark Place      2.2              NaN  Short Trip
# 648              Heritage Pines      2.2              NaN  Short Trip
# 171              Westpark Place      2.1              NaN  Short Trip
# 343              Westpark Place      2.1   Meal/Entertain  Short Trip
# 819                     Parkway      2.1          Meeting  Short Trip
# 860                     Parkway      2.1          Meeting  Short Trip
# 40                    Hazelwood      2.0   Meal/Entertain  Short Trip
# 266              Westpark Place      2.0              NaN  Short Trip
# 42               Westpark Place      1.9  Errand/Supplies  Short Trip
# 166              Westpark Place      1.9              NaN  Short Trip
# 653              Westpark Place      1.9              NaN  Short Trip
# 264                     Preston      1.7              NaN  Short Trip
# 206                 Whitebridge      1.6              NaN  Short Trip
# 495              Westpark Place      1.6              NaN  Short Trip
# 156                     Preston      1.5              NaN  Short Trip
# 595                     Parkway      1.5              NaN  Short Trip
# 263                 Whitebridge      1.4              NaN  Short Trip
# 893              Westpark Place      1.4              NaN  Short Trip
# 900              Westpark Place      1.4              NaN  Short Trip
# 889                 Whitebridge      1.2              NaN  Short Trip
# 890                 Whitebridge      1.0              NaN  Short Trip
# 516                 Whitebridge      0.6  Errand/Supplies  Short Trip
# 870                   Asheville    133.6          Meeting   Long Trip
# 1155                        NaN  12204.7              NaN   Long Trip
#
#       new_col2
# 906        8.6
# 911        4.8
# 908        4.4
# 910        4.4
# 879       30.4
# 1001      18.0
# 1033      17.6
# 410       14.4
# 647       12.0
# 60        11.4
# 80        11.4
# 173       11.2
# 58        11.0
# 565       11.0
# 978       10.8
# 826       10.6
# 1014      10.6
# 1045       9.4
# 616        9.2
# 825        6.6
# 855        4.4
# 646        2.0
# 469       34.0
# 621        9.8
# 613        2.6
# 881      391.8
# 871      183.6
# 232      272.0
# 552       56.2
# 549       44.8
# ...        ...
# 632        5.4
# 174        5.2
# 898        5.0
# 178        4.4
# 348        4.4
# 599        4.4
# 607        4.4
# 648        4.4
# 171        4.2
# 343        4.2
# 819        4.2
# 860        4.2
# 40         4.0
# 266        4.0
# 42         3.8
# 166        3.8
# 653        3.8
# 264        3.4
# 206        3.2
# 495        3.2
# 156        3.0
# 595        3.0
# 263        2.8
# 893        2.8
# 900        2.8
# 889        2.4
# 890        2.0
# 516        1.2
# 870      267.2
# 1155   24409.4
#
# [1156 rows x 9 columns]

# %% [markdown]
# #### INDEX MANIPULATION IN DATA FRAMES

# %%
### Permanently renaming columns
dfnew1 = pd.read_csv("Uber Drives 2016.csv")
dfnew1.rename(columns={'START_DATE*' : 'start_date',
                    'END_DATE*'  : 'end_date',
                     'CATEGORY*' : 'category',
                     'START*'    : 'start',
                     'STOP*'     : 'stop',
                     'MILES*'    :  'miles',
                     'PURPOSE*'   :  'purpose'}, 
                 index={0:'zero',1:'one'}, 
                 inplace=True)
dfnew1.head(10)
# Out:
#            start_date         end_date  category            start  \
# zero   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# one     1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2      1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3      1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4      1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5      1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6      1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7      1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8      1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9     1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#                  stop  miles          purpose
# zero      Fort Pierce    5.1   Meal/Entertain
# one       Fort Pierce    5.0              NaN
# 2         Fort Pierce    4.8  Errand/Supplies
# 3         Fort Pierce    4.7          Meeting
# 4     West Palm Beach   63.7   Customer Visit
# 5     West Palm Beach    4.3   Meal/Entertain
# 6          Palm Beach    7.1          Meeting
# 7                Cary    0.8          Meeting
# 8         Morrisville    8.3          Meeting
# 9            New York   16.5   Customer Visit

# %%
### INDEX MANIPULATION
## resetting indexes

# %%
#### resets index, but not inplace reset
dfnew1.reset_index(drop=True,inplace=False).head() ### will reset the index permanently


### NOTE - User defined index is showing as another column "index"
### drop will drop the user defined column as index
### inplace=True will permanently reset
# Out:
#        start_date        end_date  category        start             stop  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    miles          purpose
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
dfnew1.head()

# %%
dfnew1["my_indx"] = dfnew['miles']

# %%
dfnew1.head()
# Out:
#           start_date        end_date  category        start             stop  \
# zero  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# one    1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2     1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3     1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4     1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#       miles          purpose  my_indx
# zero    5.1   Meal/Entertain      5.1
# one     5.0              NaN      5.0
# 2       4.8  Errand/Supplies      4.8
# 3       4.7          Meeting      4.7
# 4      63.7   Customer Visit     63.7

# %%
### set the index of dataframe to column States
dfnew1.set_index('my_indx',inplace=False).head()
# Out:
#              start_date        end_date  category        start  \
# my_indx
# 5.1      1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce
# 5.0       1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce
# 4.8      1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce
# 4.7      1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce
# 63.7     1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce
#
#                     stop  miles          purpose
# my_indx
# 5.1          Fort Pierce    5.1   Meal/Entertain
# 5.0          Fort Pierce    5.0              NaN
# 4.8          Fort Pierce    4.8  Errand/Supplies
# 4.7          Fort Pierce    4.7          Meeting
# 63.7     West Palm Beach   63.7   Customer Visit

# %%
#### adding a new column to data frame 
### set that column as index

# %%
newstring = 'CA NY NJ OH CO'

# %%
newx = newstring.split()

# %%
newx

# %%
df1['States'] = newx
df1

# %%
df1.set_index('States')

### column states has now become index

# %%
df1
### note that States is not index because inplace=False

# %%
#### difference between reset and set index is
#### reset index resets to new index and makes the old index as a column in the data frame
#### set index completely overrides the old index
### note both reset and set will become permanent ONLY when using INPLACE argument

# %% [markdown]
# #### GROUP BY IN PANDAS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Groupby Summarize

# %%
dfnew.head(10)
# Out:
#            start_date         end_date  category            start  \
# zero   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# one     1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2      1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3      1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4      1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5      1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6      1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7      1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8      1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9     1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#                  stop  miles          purpose   miles_cat  new_col2
# zero      Fort Pierce    5.1   Meal/Entertain   Long Trip      10.2
# one       Fort Pierce    5.0              NaN  Short Trip      10.0
# 2         Fort Pierce    4.8  Errand/Supplies  Short Trip       9.6
# 3         Fort Pierce    4.7          Meeting  Short Trip       9.4
# 4     West Palm Beach   63.7   Customer Visit   Long Trip     127.4
# 5     West Palm Beach    4.3   Meal/Entertain  Short Trip       8.6
# 6          Palm Beach    7.1          Meeting   Long Trip      14.2
# 7                Cary    0.8          Meeting  Short Trip       1.6
# 8         Morrisville    8.3          Meeting   Long Trip      16.6
# 9            New York   16.5   Customer Visit   Long Trip      33.0

# %%
# for each start loc find the mean distance travelled
dfnew.groupby("start").agg("mean").head()
# Out:
#                miles   new_col2
# start
# Agnew       2.775000   5.550000
# Almond     15.200000  30.400000
# Apex        5.341176  10.682353
# Arabi      17.000000  34.000000
# Arlington   4.900000   9.800000

# %%
# for each start loc find the mean & the total dist travelled
dfx=dfnew.groupby("start").agg(["mean","sum"]).head()

# %%
dfx.columns
# Out:
# MultiIndex(levels=[['miles', 'new_col2'], ['mean', 'sum']],
#            labels=[[0, 0, 1, 1], [0, 1, 0, 1]])

# %%
import numpy as np
import pandas as pd

# %%
sales_data = {'Company':['GooG','GooG','MSFT','MSFT','FB','FB'],
              'Person' :['John Smith','Jane Doe','Amy','Andy','Charlie','Karla'],
              'Sales'  :[200,400,600,1000,1200,10000]}

# %%
### create a data frame using dictionary sales_data
sales_df = pd.DataFrame(data=sales_data)

# %%
sales_df
# Out:
#   Company      Person  Sales
# 0    GooG  John Smith    200
# 1    GooG    Jane Doe    400
# 2    MSFT         Amy    600
# 3    MSFT        Andy   1000
# 4      FB     Charlie   1200
# 5      FB       Karla  10000

# %%
#### using Group By Method. group by "company" column

grpbycomp = sales_df.groupby('Company')
grpbycomp
print(type(grpbycomp))

### note that the output is a group by object
# Out:
# <class 'pandas.core.groupby.groupby.DataFrameGroupBy'>

# %%
### mean of sales by company or average sales for each company
grpbycomp.mean()

### for eg mean sales of facebook is (1200+10000)/2) = 5600 
### outputs a data frame with index called company and sales
### this allows us to further process the data
# Out:
#          Sales
# Company
# FB        5600
# GooG       300
# MSFT       800

# %%
### to find total sales per company
grpbycomp.sum()
# Out:
#          Sales
# Company
# FB       11200
# GooG       600
# MSFT      1600

# %%
#### to get the overall sales of facebook
grpbycomp.sum().loc['FB']
# Out:
# Sales    11200
# Name: FB, dtype: int64

# %%
### smart coding 
sales_df.groupby('Company').sum().loc['FB']
# Out:
# Sales    11200
# Name: FB, dtype: int64

# %%
### smart coding 
res= sales_df.groupby('Company').sum().loc[['FB','GooG']]
print(res)
# Out:
#          Sales
# Company
# FB       11200
# GooG       600

# %%
#### to get the overall sales of Google
grpbycomp.sum().loc['GooG']

# %%
### smart coding 
df.groupby('Company').sum().loc['GooG']

# %%
### other ways of writing expression with groupby
#### groupby (column). aggregatefunction
df.groupby('Company').sum().loc['FB']

# %%
df.groupby('Company').sum().loc['GooG']

# %%
df

# %%
### to count the number of persons in each company

df.groupby('Company').count()

# %%
### count of rows in Sales column for every company
df.groupby('Company').count()['Sales']

# %%
### Max Sales in every company

df.groupby('Company').max()

# %%
df.groupby('Company').min()

# %%
#### group by with describe method, gives min,max, mean , count, std deviation, \
### 1st quartile, 2nd quartile, 3rd quartile.
### All your summary statistics will be displayed by describe

sales_df.groupby('Company').describe()
# Out:
#         Sales
#         count    mean          std     min     25%     50%     75%      max
# Company
# FB        2.0  5600.0  6222.539674  1200.0  3400.0  5600.0  7800.0  10000.0
# GooG      2.0   300.0   141.421356   200.0   250.0   300.0   350.0    400.0
# MSFT      2.0   800.0   282.842712   600.0   700.0   800.0   900.0   1000.0

# %%
### describe on the whole data frame
df.describe()

# %%
#### use transpose method on describe method output to transpose rows and columns
sales_df.groupby('Company').describe().transpose()
# Out:
# Company                FB        GooG         MSFT
# Sales count      2.000000    2.000000     2.000000
#       mean    5600.000000  300.000000   800.000000
#       std     6222.539674  141.421356   282.842712
#       min     1200.000000  200.000000   600.000000
#       25%     3400.000000  250.000000   700.000000
#       50%     5600.000000  300.000000   800.000000
#       75%     7800.000000  350.000000   900.000000
#       max    10000.000000  400.000000  1000.000000

# %%
### describe for every column
df.describe()['Sales']

# %%
### for loop to iterate through a data frame columns
for key, value in df100.iteritems():
    value +=1                        ## value = value+1
    print(key,value)

# %%
df200 = pd.DataFrame(np.random.rand(5,4),columns=['col1','col2','col3','col4'])

# %%
df200

# %%
### for loop to iterate through a data frame rows

for key, value in df200.iterrows():
    value= value+100
    print(key,value)

# %%
df200[['col1','col2']]

# %% [markdown]
# ### Merging, Concatenating, Joining

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ## Concatenation
#
# Concatenation basically glues together DataFrames. Keep in mind that dimensions should match along the axis you are concatenating on. You can use **pd.concat** and pass in a list of DataFrames to concatenate together:

# %%
### the axis of concatenation is rows - because by default axis=0 represents rows. so concatenation happens on rows
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 0    A4   B4   C4   D4
# 1    A5   B5   C5   D5
# 2    A6   B6   C6   D6
# 3    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1)

# %% [markdown]
# _____
#     ## Example DataFrames - dictionary

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.concat([left,right])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.
#      A    B    C    D key
# 0   A0   B0  NaN  NaN  K0
# 1   A1   B1  NaN  NaN  K1
# 2   A2   B2  NaN  NaN  K2
# 3   A3   B3  NaN  NaN  K3
# 0  NaN  NaN   C0   D0  K0
# 1  NaN  NaN   C1   D1  K1
# 2  NaN  NaN   C2   D2  K2
# 3  NaN  NaN   C3   D3  K3

# %%
pd.concat([left,right],axis=1)

# %%
left

# %%
right

# %% [markdown]
# ___

# %% [markdown]
# ## Merging
#
# The **merge** function allows you to merge DataFrames together using a similar logic as merging SQL Tables together. For example:

# %%
print(left)
print(right)
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %% [markdown]
# Or to show a more complicated example:

# %%
left1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right1 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                         'C': ['C0', 'C1', 'C2', 'C3'],
                         'D': ['D0', 'D1', 'D2', 'D3']})

# %%
print(left1)
print(right1)

# %%
pd.merge(left1, right1, on=['key1', 'key2'])

# %%
print(left)

# %%
print(right)

# %%
print(left1)
print(right1)

# %%
pd.merge(left1, right1, how='outer', on=['key1', 'key2'])   ### similar to sql full outer join

# %%
print(left1)
print(right1)

# %%
pd.merge(left1, right1, how='right', on=['key1', 'key2'])        ### similar to sql right outer join

# %%
pd.merge(left1, right1, how='left', on=['key1', 'key2'])

# %% [markdown]
# ## Joining
# Joining is a convenient method for combining the columns of two potentially differently-indexed DataFrames into a single result DataFrame.

# %%
    df1 =pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

df2= pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
print(df1)
print(df2)

# %%
df1.join(df2)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
df2.join(df1)

# %%
left.join(right, how='outer')

# %% [markdown]
# ## Treating missing values
# 1) using dropna() , remove all the elements with missing values. elements here can be elements of an array, row of a file etc..
#
# 2) Impute missing values with meaningful valid value. Imputation means replacement of missing values with valid values
#    - what meaningful values
#      - in case of a numeric variable or column, missing values are replaced by average value of all the elements in the column
#                   A
#                   1
#                   2
#                   3
#                   Nan            imputation value = mean(A)
#                   5
#
#      - in case of a numeric variable or column, missing values are replaced by median value of all the elements in the column
#                   A
#                   1
#                   2
#                   3
#                   Nan            imputation value = median(A)
#                   5
#
#      - - in case of a numeric variable or column, missing values are replaced by mode value of all the elements in the column
#                   A
#                   1
#                   2
#                   3
#                   Nan            imputation value = mode(A)
#                   5
#
#      - in case of a categorical variable or column, missing values are replaced by mode - frequent occuring value in the column
#                   A
#                   cat1
#                   cat1
#                   cat1
#                   Nan            imputation value = cat1
#                   cat5

# %%
dfnew.head()

# %%
## Count missing values
dfnew.isnull().sum()

# %% [markdown]
# fill missing values with most common/frequently occurring

# %%
# Fill NA with most common values
dfnew["purpose"].value_counts()

# %%
dfnew = dfnew.fillna({"purpose":"Meeting"})

# %%
dfnew["purpose"].value_counts()

# %%
### removing missing values in rows
dfnew.dropna(axis=0,inplace=False).head()

# %%
### removing missing values in columns
dfnew.dropna(axis=1,inplace=False).head()

# %%
#### row 1 has 3 Non NaN values (no missing values)
#### row 2 has 2 Non NaN values 
### row 3 has 1 Non NaN value 
#### we can set the threshold to retain Row1 and drop only row 2

dfnew.dropna(axis=0,thresh=2,inplace=False)

### observe second row is retained becausee it had 2 NON NaN values

# %% [markdown]
# ###### Imputing Missing Values

# %%
##### replace missing values using value parameter

# %%
### one way to fill missing values is by finding the mean of that column and replacing missing valuees
### with that mean.
### note below that df['A'].mean() helps in getting the mean of column A
#df3['A'].fillna(value=dfnew['miles'].mean())

# %%
#### DATA INPUT OUTPUT USING EXCEL,HTML,SQL

# %% [markdown]
# DATA INPUT AND OUTPUT USING PANDAS
# CSV
# EXCEL
# HTML
# SQL
#
# When you install Jupyter via anaconda distribution, all the below packages come in by defauly
#
# When installing Jupyter outside anaconda distribution, you will need to use the following install commands
# Libraries that need to be installed with pip or conda
# conda install sqlalchemy
# conda install lxml
# conda install html5lib
# conda install BeautifulSoup4
#
# to read any file, type read_ and click tab

# %%
import pandas as pd

# %%
import numpy as np

# %%
### reading excel file with .xls or .xlsx extension
df_weightloss = pd.read_excel('DietWeightLoss.xls')

# %%
### use tab to understand diffrent files that can be read using read
## pd.read_

# %%
df_weightloss

# %% [markdown]
# WRITE INTO A FILE FROM A DATAFRAME

# %%
### writing to an excel file 
## weightloss.to_excel('new_diet_data.xls')

# %%
df_weightloss.to_excel('feb2_weightloss.xls')

# %%
### to check whether the new file got created - read the file
pd.read_excel('feb2_weightloss.xls')

# %%
df_weightloss.to_csv('feb2_weightloss.csv')

# %%
newdietdf = pd.read_excel('new_diet_weightloss.xls')

# %%
print(type(newdietdf))

# %%
## to get the top 5 records of your data frame 
newdietdf.head()

# %%
### to get a specific number of records from data frame
newdietdf.head(20)

# %%
### to get the bottom 5 records from the dataframe
newdietdf.tail()

# %%
### to get the specific number of records from the bottom of the file
newdietdf.tail(20)

# %%
df.head()

# %%
#### writing into a file from dataframe
##### click tab key after df.to to get all options
### below creates a My_Ouput.csv file
#### reason for index = False is index also gets saved as a column

# %%
df_housing = pd.read_csv("housing_prices.csv")

# %%
df_housing.head()

# %%
df_housing.info()

# %%
df_housing.to_csv('df_housing_out',sep=',')

# %%
dfhousingout=pd.read_csv('df_housing_out')  #### note the column Unnamed which also stores index
dfhousingout.head()  #### note the column Unnamed which also stores index

# %%
df_housing.to_csv('df_housing_out_new',index=False)

# %%
pd.read_csv('df_housing_out_new').head()

# %%
pd.read_csv('My_Output1')  
#pd.read_csv('My_Output1')  #### note the column Unnamed which also stores index

# %%
df.to_csv('My_Output2',index=False)

# %%
pd.read_csv('My_Output2').head()

# %% [markdown]
# READING AND WRITING FROM EXCEL FILES
#       PANDAS CAN ONLY IMPORT DATA.
#       DOES NOT IMPORT FORMULAS OR MACROS
#       TRYING TO READ EXCEL FILE WITH FORMULAS MAY CAUSE PANDAS TO CRASH
#       WE MAY BE ASKED TO INSTALL XLRD LIBRARY(IDEALLY INSTALLED AUTOMATICALLY WITH ANACONDA
#       Distribution)
#       IF ERROR
#          conda install xlrd

# %%
#### to read an excel file, pass file name and sheet name. if no sheet name given, sheet1 is assumed
### pandas reads as a dataframe
df=pd.read_excel('myexcel.xlsx',sheet_name='newsheet')
df

# %%
df1=pd.read_excel('myexcel.xlsx',sheet_name='newsheet1')
df1

# %%
df2=pd.read_excel('myexcel.xlsx',sheet_name='newsheet2')
df2

# %%
df5=pd.read_excel('myexcel.xlsx')

# %%
print(df5)

# %%
#### write to excel
df5.to_excel('myoutputxl.xlsx',sheet_name='NewSheetOut2')
## over writes the existing sheet

# %%
### example for writing into a new shete and append to existing

# %%
dfout1=pd.read_excel('myoutputxl.xlsx',sheet_name='NewSheetOut2')

# %%
dfout1

# %% [markdown]
# READING FROM HTML INPUT

# %%
datahtml = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')

#### notee that depending on the size of html,
#### jupyter will take time to read and process the data.
#### output is a list
#### this command, picks up every table element that is present in html file
#### table references markings (can be found in the html source code "view source")
### this command, creates a list of all table elements and converts each item to data frame)

# %%
type(datahtml)

# %%
len(datahtml)

# %%
type(datahtml)

# %%
#### to check the first item in list --
### there is only onee table in the website...index 0 of list datahtml
datahtml[0]

# %%
### look at top 5 rows
datahtml[0].head()

# %%
### bottom 5 rows
datahtml[0].tail()

# %%
### bottom 10 rows
datahtml[0].head(10)

# %%
datahtml[0].tail(10)

# %% [markdown]
# ### Groupby Summarize

# %%
# for each start loc find the mean distance travelled
dfnew.groupby("start")["miles"].agg("mean").head()

# %%
# for each start loc find the mean & the total dist travelled
dfnew.groupby("start").agg(["mean","sum"]).head()

# %% [markdown]
# ### Assignments
#
# 1) Find mean quarterly sales by store
#
# 2) Find the month with highest sales for each store

# %% [markdown]
# ## Other/Miscellaneous topics

# %% [markdown]
# ### Missing value treatment

# %%
df.isnull().sum()

# %%
## Count missing values
df.isnull().sum()

# %%
# Fill NA with most common values
df["PURPOSE*"].value_counts()

# %%
df = df.fillna({"PURPOSE*":"Meeting"})

# %%
df["PURPOSE*"].value_counts()

# %% [markdown]
# ### Matrix operations use case

# %% [markdown]
# ### Example 1 - compute month on month growth in sales

# %%
store_sales.head()

# %%
sales_mat = np.array(store_sales.iloc[:,2:])

# %%
sales_mat

# %%
sales_mat_lag = sales_mat[:,1:]
sales_mat_lag

# %%
sales_mat_lag = sales_mat[:,1:]
sales_mat_lag = np.c_[sales_mat_lag,np.zeros(100)]

# %%
sales_diff = sales_mat_lag - sales_mat

# %%
perct_change = pd.DataFrame(sales_diff/sales_mat)

# %%
perct_change.head()

# %% [markdown]
# ### Example 1 - compute net revenue

# %%
profit_mat = np.random.uniform(low=0.05, high=0.25, size=(100,12))

# %%
## Find total annual profit for each store
profit_mat = profit_mat.transpose()

# %%
profit_mat.shape

# %%
prof_matrix = np.dot(sales_mat,profit_mat)

# %%
prof_matrix.shape
